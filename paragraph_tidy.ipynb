# %%
import pandas as pd

# %%
random_par = pd.read_csv("download_paragraphs.csv", sep=",")

# %%
random_par = random_par.drop_duplicates()
random_par
# Out:
#                                                   text
# 0    James was leaning against the empty guard desk...
# 1    There was no clock on the nightstand between t...
# 2    Finley should’ve been happier — he should’ve b...
# 3    Inside a Belizean cave, you wade deeper into g...
# 4    Sophie had forgotten him by then. Not complete...
# ..                                                 ...
# 649  "Are you getting my texts???" she texted to hi...
# 650  Sometimes it's the first moment of the day tha...
# 651  "Explain to me again why I shouldn't cheat?" h...
# 652  Finding the red rose in the mailbox was a plea...
# 653  Betty decided to write a short story and she w...
#
# [654 rows x 1 columns]

# %%
random_par['text_new'] = random_par['text'].str.split('|').str[0]
random_par
# Out:
#                                                   text  \
# 0    James was leaning against the empty guard desk...
# 1    There was no clock on the nightstand between t...
# 2    Finley should’ve been happier — he should’ve b...
# 3    Inside a Belizean cave, you wade deeper into g...
# 4    Sophie had forgotten him by then. Not complete...
# ..                                                 ...
# 649  "Are you getting my texts???" she texted to hi...
# 650  Sometimes it's the first moment of the day tha...
# 651  "Explain to me again why I shouldn't cheat?" h...
# 652  Finding the red rose in the mailbox was a plea...
# 653  Betty decided to write a short story and she w...
#
#                                               text_new
# 0    James was leaning against the empty guard desk...
# 1    There was no clock on the nightstand between t...
# 2    Finley should’ve been happier — he should’ve b...
# 3    Inside a Belizean cave, you wade deeper into g...
# ...

# %%
## add all other paragraph text preprocessing here before sending to model

# %%
random_par['text_new'].to_csv("tidy_paragraphs.csv", index=False)
